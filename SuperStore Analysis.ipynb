# %% [markdown]
# # SuperStore Analysis

# %%
# importing packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# loading the dataset
df=pd.read_csv('Superstore.csv',encoding='windows-1252')

# %%
# printing the first 5 rows
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# printing the last 5 rows
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# checking the shape of dataset
df.shape
# Out:
# (9994, 21)

# %%
# checking if the dataset contains any NA value
df.isna().sum().reset_index()
# Out:
#             index  0
# 0          Row ID  0
# 1        Order ID  0
# 2      Order Date  0
# 3       Ship Date  0
# 4       Ship Mode  0
# 5     Customer ID  0
# 6   Customer Name  0
# 7         Segment  0
# 8         Country  0
# 9            City  0
# 10          State  0
# 11    Postal Code  0
# 12         Region  0
# 13     Product ID  0
# 14       Category  0
# 15   Sub-Category  0
# 16   Product Name  0
# 17          Sales  0
# 18       Quantity  0
# 19       Discount  0
# 20         Profit  0

# %%
# checking if the dataset contains any duplicate value
df.duplicated().sum()
# Out:
# 0

# %%
# checking the datatype of every column
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
# seperating the categorical features
df_cat=df[['Ship Mode','Customer ID','Customer Name','Segment','Country','City','State','Region','Product ID','Category','Sub-Category','Product Name']]

# %%
df_cat.head()
# Out:
#         Ship Mode Customer ID    Customer Name    Segment        Country  \
# 0    Second Class    CG-12520      Claire Gute   Consumer  United States
# 1    Second Class    CG-12520      Claire Gute   Consumer  United States
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate  United States
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States
#
#               City       State Region       Product ID         Category  \
# 0        Henderson    Kentucky  South  FUR-BO-10001798        Furniture
# 1        Henderson    Kentucky  South  FUR-CH-10000454        Furniture
# 2      Los Angeles  California   West  OFF-LA-10000240  Office Supplies
# 3  Fort Lauderdale     Florida  South  FUR-TA-10000577        Furniture
# 4  Fort Lauderdale     Florida  South  OFF-ST-10000760  Office Supplies
#
#   Sub-Category                                       Product Name
# ...

# %%
# number of unique values in categorical data
for i in df_cat.columns:
    print(i,':',df[i].nunique())
# Out:
# Ship Mode : 4
# Customer ID : 793
# Customer Name : 793
# Segment : 3
# Country : 1
# City : 531
# State : 49
# Region : 4
# Product ID : 1862
# Category : 3
# Sub-Category : 17
# Product Name : 1850

# %% [markdown]
# ## Exploratory Data Analysis - EDA

# %%
# What are the top selling products in the superstore?

# %%
product_group=df.groupby(["Product Name"]).sum(numeric_only=True)["Sales"]

# %%
top_selling_products=product_group.sort_values(ascending=False)
top_5_products=pd.DataFrame(top_selling_products.head())
top_5_products
# Out:
#                                                         Sales
# Product Name
# Canon imageCLASS 2200 Advanced Copier               61599.824
# Fellowes PB500 Electric Punch Plastic Comb Bind...  27453.384
# Cisco TelePresence System EX90 Videoconferencin...  22638.480
# HON 5400 Series Task Chairs for Big and Tall        21870.576
# GBC DocuBind TL300 Electric Binding System          19823.479

# %%
top_5_products.plot(kind="bar")
plt.title("Top 5 Selling Products in SuperStore")
plt.xlabel("Product Names")
plt.ylabel("Sales")
plt.show()

# %%
# top-profitable products ?

# %%
product_group=df.groupby(["Product Name"]).sum(numeric_only=True)["Profit"]
profitable_products=product_group.sort_values(ascending=False)
top_5_profitable_products=pd.DataFrame(profitable_products.head())
top_5_profitable_products
# Out:
#                                                         Profit
# Product Name
# Canon imageCLASS 2200 Advanced Copier               25199.9280
# Fellowes PB500 Electric Punch Plastic Comb Bind...   7753.0390
# Hewlett Packard LaserJet 3310 Copier                 6983.8836
# Canon PC1060 Personal Laser Copier                   4570.9347
# HP Designjet T520 Inkjet Large Format Printer -...   4094.9766

# %%
top_5_profitable_products.plot(kind="bar")
plt.title("Top 5 Profit Products in SuperStore")
plt.xlabel("Product Name")
plt.ylabel("Total Profit")
plt.show()

# %%
# Are the top-selling products the most profitable?

# %%
top_5_products.index==top_5_profitable_products.index
# Out:
# array([ True,  True, False, False, False])

# %%
df["Region"].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
product=df[df["Product Name"]=="Canon imageCLASS 2200 Advanced Copier"]

# %%
region_group=product.groupby(["Region"]).mean(numeric_only=True)[["Sales","Profit"]]

# %%
region_group.plot(kind="bar")
plt.show()

# %%
product1=df[df["Product Name"]=="Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind"]
region1_group=product1.groupby(["Region"]).mean(numeric_only=True)[["Sales","Profit"]]
region1_group.plot(kind="bar")
plt.show()

# %%
product_fellowes=df[(df["Product Name"]=="Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind") & (df["Region"]=="Central")]

# %%
product_fellowes
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2846    2847  CA-2017-152093   9/10/2017   9/15/2017  Standard Class
# 5310    5311  CA-2017-131254  11/19/2017  11/21/2017     First Class
# 7683    7684  CA-2015-120782   4/28/2015    5/1/2015     First Class
#
#      Customer ID    Customer Name      Segment        Country     City  ...  \
# 2846    SN-20560     Skye Norling  Home Office  United States  Chicago  ...
# 5310    NC-18415      Nathan Cano     Consumer  United States  Houston  ...
# 7683    SD-20485  Shirley Daniels  Home Office  United States  Midland  ...
#
#      Postal Code   Region       Product ID         Category Sub-Category  \
# 2846       60653  Central  OFF-BI-10003527  Office Supplies      Binders
# 5310       77095  Central  OFF-BI-10003527  Office Supplies      Binders
# 7683       48640  Central  OFF-BI-10003527  Office Supplies      Binders
#
#                                            Product Name     Sales  Quantity  \
# ...

# %%
product_fellowes_plot=df[(df["Product Name"]=="Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind") & (df["Region"]=="Central")]
product_fellowes_plot["Discount"].plot(kind="bar")
plt.show()

# %%
# Top 5 products by quantity

# %%
productid=df.groupby(['Product ID']).sum(numeric_only=True)[['Quantity']]
top_5_productid_sales=productid.sort_values(by='Quantity',ascending=False).head()

# %%
top_5_productid_sales
# Out:
#                  Quantity
# Product ID
# TEC-AC-10003832        75
# OFF-PA-10001970        70
# OFF-BI-10001524        67
# FUR-CH-10002647        64
# OFF-BI-10002026        64

# %%
top_5_productid_sales.plot(kind='bar')
plt.ylabel('Quantity')
plt.show()

# %% [markdown]
# # What is the sales trend over time (monthly, yearly)?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df['Order Date']=pd.to_datetime(df['Order Date'],errors='coerce')

# %% [markdown]
# #### Sales over time

# %%
monthly_sales=df.groupby(['Order Date'],as_index=False).sum(numeric_only=True)

# %%
monthly_sales=monthly_sales.set_index('Order Date')

# %%
monthly_sales = monthly_sales.resample('M').sum()

# %%
monthly_sales
# Out:
#              Row ID  Postal Code        Sales  Quantity  Discount      Profit
# Order Date
# 2014-01-31   346176      4342297   14236.8950       284     10.00   2450.1907
# 2014-02-28   272235      3049775    4519.8920       159      8.10    862.3084
# 2014-03-31   871575      8314538   55691.0090       585     26.30    498.7299
# 2014-04-30   690625      7723827   28295.3450       536     14.85   3488.8352
# 2014-05-31   611708      6497804   23648.2870       466     18.95   2738.7096
# 2014-06-30   491794      6827435   34595.1276       521     23.22   4976.5244
# 2014-07-31   746403      9046189   33946.3930       550     24.55   -841.4826
# 2014-08-31   729301      8628386   27909.4685       609     20.05   5318.1050
# 2014-09-30  1298740     14521813   81777.3508      1000     42.87   8328.0994
# 2014-10-31   865655      9703910   31453.3930       573     25.45   3448.2573
# 2014-11-30  1605852     18115551   78628.7167      1219     48.07   9292.1269
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(monthly_sales['Sales'])
plt.title('Monthly Sales Trend')
plt.xlabel('Order Date')
plt.ylabel('Sales')
plt.show()

# %%
# Years Sales
year_sales=monthly_sales.resample('Y').sum()

# %%
plt.figure(figsize=(20,10))
plt.plot(year_sales['Sales'])
plt.xlabel('Order Date')
plt.ylabel('Sales')
plt.title('Yearly Sales Trend')
plt.show()

# %% [markdown]
# #### Profit Over Time

# %%
monthly_sales=df.groupby(['Order Date'],as_index=False).sum(numeric_only=True)
monthly_sales=monthly_sales.set_index('Order Date')
monthly_sales=monthly_sales.resample('M').sum()
plt.figure(figsize=(25,10))
plt.plot(monthly_sales['Profit'])
plt.xlabel('Order Date')
plt.ylabel('Profit')
plt.title('Monthly Profit Trend')
plt.show()

# %%
yearly_profit=monthly_sales.resample('Y').sum()
plt.figure(figsize=(25,10))
plt.plot(yearly_profit['Profit'])
plt.xlabel('Order Date')
plt.ylabel('Profit')
plt.title('Yearly Profit Trend')
plt.show()

# %% [markdown]
# # Which region & place generates the most sales?

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df_place=df[['Country', 'City', 'State','Region']]
df_place.head()
# Out:
#          Country             City       State Region
# 0  United States        Henderson    Kentucky  South
# 1  United States        Henderson    Kentucky  South
# 2  United States      Los Angeles  California   West
# 3  United States  Fort Lauderdale     Florida  South
# 4  United States  Fort Lauderdale     Florida  South

# %%
for j in df_place.columns:
    print(j,":",df_place[j].nunique())
# Out:
# Country : 1
# City : 531
# State : 49
# Region : 4

# %%
df_place=df[['Country', 'City', 'State','Region','Sales','Profit']]
df_place.head()
# Out:
#          Country             City       State Region     Sales    Profit
# 0  United States        Henderson    Kentucky  South  261.9600   41.9136
# 1  United States        Henderson    Kentucky  South  731.9400  219.5820
# 2  United States      Los Angeles  California   West   14.6200    6.8714
# 3  United States  Fort Lauderdale     Florida  South  957.5775 -383.0310
# 4  United States  Fort Lauderdale     Florida  South   22.3680    2.5164

# %%
region_sales=df_place.groupby(['Region'],as_index=False).sum(numeric_only=True)
region_sales.sort_values(by='Sales',ascending=False,inplace=True)
plt.figure(figsize=(15,5))
plt.bar(region_sales['Region'],region_sales['Sales'],align='center')
plt.xlabel('Region')
plt.ylabel('Sales')
plt.title('Sales generated by Region')
plt.show()

# %%
region_profit=df_place.groupby(['Region'],as_index=False).sum(numeric_only=True)
region_profit.sort_values(by='Profit',ascending=False,inplace=True)
plt.figure(figsize=(15,5))
plt.bar(region_profit['Region'],region_profit['Profit'],align='center')
plt.xlabel('Region')
plt.ylabel('Profit')
plt.title('Profit generated by Region')
plt.show()

# %%
state_sales=df_place.groupby(['State'],as_index=False).sum(numeric_only=True)
state_sales.sort_values(by='Sales',ascending=False,inplace=True)
plt.figure(figsize=(25,10))
plt.bar(state_sales['State'],state_sales['Sales'],align='center')
plt.xlabel('State')
plt.ylabel('Sales')
plt.title('Sales generated by State')
plt.xticks(rotation=90)
plt.show()

# %%
city_sales=df_place.groupby(['City'],as_index=False).sum(numeric_only=True)
city_sales.sort_values(by='Sales',ascending=False,inplace=True)
plt.figure(figsize=(25,10))
plt.bar(city_sales['City'].head(),city_sales['Sales'].head(),align='center')
plt.xlabel('City')
plt.ylabel('Sales')
plt.title('Top 5 Cities By Sales')
plt.xticks(rotation=90)
plt.show()

# %%
city_profit=df_place.groupby(['City'],as_index=False).sum(numeric_only=True)
city_profit.sort_values(by='Profit',ascending=False,inplace=True)
plt.figure(figsize=(25,10))
plt.bar(city_profit['City'].head(),city_profit['Profit'].head(),align='center')
plt.xlabel('City')
plt.ylabel('Profit')
plt.title('Top 5 Cities By Profit')
plt.xticks(rotation=90)
plt.show()

# %%
city_sales['City'].head()
# Out:
# 329    New York City
# 266      Los Angeles
# 452          Seattle
# 438    San Francisco
# 374     Philadelphia
# Name: City, dtype: object

# %% [markdown]
# # What is the impact of discounts on sales?

# %%
df['Discount'].value_counts()
# Out:
# 0.00    4798
# 0.20    3657
# 0.70     418
# 0.80     300
# 0.30     227
# 0.40     206
# 0.60     138
# 0.10      94
# 0.50      66
# 0.15      52
# 0.32      27
# 0.45      11
# Name: Discount, dtype: int64

# %%
discount_group=df.groupby(['Discount']).sum(numeric_only=True)[['Sales']]
ax=discount_group.plot(kind='bar')
ax.set_ylabel('Sales')
plt.show()

# %%
plt.scatter(df['Discount'],df['Sales'])
plt.xlabel('Discount')
plt.ylabel('Sales')
plt.show()

# %%
discount_group=df.groupby(['Discount']).sum(numeric_only=True)[['Profit']]
ax=discount_group.plot(kind='bar')
ax.set_ylabel('Profit')
plt.show()

# %%
# verage profit for each category
avg_profit_by_category=df.groupby(['Category'],as_index=False).mean(numeric_only=True)[['Category','Profit']]
avg_profit_by_category
# Out:
#           Category     Profit
# 0        Furniture   8.699327
# 1  Office Supplies  20.327050
# 2       Technology  78.752002

# %%
df['Profit Margin']=df['Profit']/df['Sales']

# %%
avg_profit_margin_by_category=df.groupby(['Category']).mean(numeric_only=True)[['Profit Margin']]
avg_profit_margin_by_category.plot(kind='bar')
plt.xlabel('Product Category')
plt.ylabel('Average Profit Margin')
plt.title("Average Profit Margin by Product Category")
plt.show()

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Profit Margin'],
#       dtype='object')

# %% [markdown]
# # Customers

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
pivot_tables=df.pivot_table(index='Segment',columns='Ship Mode',values='Sales',aggfunc='sum')
pivot_tables
# Out:
# Ship Mode    First Class   Same Day  Second Class  Standard Class
# Segment
# Consumer     159168.9650  60596.359   231498.9496     710137.0714
# Corporate    105858.4699  45121.323   146126.0388     409040.5351
# Home Office   86400.9880  22645.443    81568.5810     239038.1365

# %%
pivot_tables.plot(kind='bar',stacked=False)
plt.show()

# %%
pivot_tables_profit=df.pivot_table(index='Segment',columns='Ship Mode',values='Profit',aggfunc='sum')
pivot_tables_profit.plot(kind='bar',stacked=False)
plt.show()
